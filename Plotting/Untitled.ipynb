# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = pd.read_csv("1852grl_samples.csv")

# %%
file.head(5)
# Out:
#    Unnamed: 0      Strike         Length         Width       Slip   Longitude  \
# 0           0  190.000013  133325.981000  84500.964600  21.830928  130.850829
# 1           1  188.115846  133324.709027  83733.179699  21.817947  130.871025
# 2           2  189.246124  130556.843001  84146.003567  21.903907  131.005842
# 3           3  190.097471  131723.558997  82493.195791  21.669837  130.977406
# 4           4  192.617912  133210.837856  82494.524614  21.514882  131.001890
#
#    Latitude
# 0 -5.455714
# 1 -5.461472
# 2 -5.517647
# 3 -5.693022
# 4 -5.711233

# %%
plt.plot(range(len(file["Length"])),file['Length'])
plt.show()

# %%
plt.plot(range(len(file["Strike"])),file['Strike'])
plt.show()

# %%
plt.plot(range(len(file["Width"])),file['Width'])
plt.show()

# %%
plt.plot(range(len(file["Slip"])),file['Slip'])
plt.show()

# %%
plt.hist(file['Length'], bins =100)
plt.show()

# %%
plt.hist(file['Strike'], bins =100)
plt.show()

# %%
plt.hist(file['Width'], bins =100)
plt.show()

# %%
plt.hist(file['Slip'], bins =100)
plt.show()

# %%
plt.hist(file['Longitude'], bins =100)
plt.show()

# %%
plt.hist(file['Latitude'],bins=100)
plt.show()

# %%
plt.hist2d(file['Longitude'],file['Latitude'], bins=(100, 100), cmap="twilight")
plt.colorbar()
plt.show()

# %%
fig = plt.figure()
X,Y = file['Longitude'],file['Latitude']
Z = file['Width']
plt.scatter(X, Y, Z, c=Z,cmap='viridis', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      57     try:
# ---> 58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/projections/__init__.py in get_projection_class(self, name)
#      24         """
# ---> 25         return self._all_projection_types[name]
#      26
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-4cf902d36cdc> in <module>
#       1 fig = plt.figure()
# ----> 2 ax = plt.axes(projection='3d')
#       3 X,Y = file['Longitude'],file['Latitude']
#       4 Z = file['Width']
# ...
